# %% [markdown]
# ## Applying libraries

# %%
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPooling2D, AveragePooling2D

import matplotlib.pyplot as plt
import numpy as np

import os

from sklearn.model_selection import train_test_split

# %%
link_train_benign = '/Users/dmitry/Desktop/python/cancer detection/data/train/benign/'
link_train_malignant = '/Users/dmitry/Desktop/python/cancer detection/data/train/malignant/'
link_test_benign = '/Users/dmitry/Desktop/python/cancer detection/data/test/benign/'
link_test_malignant = '/Users/dmitry/Desktop/python/cancer detection/data/test/malignant/'

train_benign_list = os.listdir(link_train_benign)
train_malignant_list = os.listdir(link_train_malignant)
test_benign_list = os.listdir(link_test_benign)
test_malignant_list = os.listdir(link_test_malignant)

# %% [markdown]
# ## Adding files

# %%
image_width = 100
image_height = 100

link_data_train = '/Users/dmitry/Desktop/python/cancer detection/data/train'
link_data_test = '/Users/dmitry/Desktop/python/cancer detection/data/test'

link_train_benign = '/Users/dmitry/Desktop/python/cancer detection/data/train/benign/'
link_train_malignant = '/Users/dmitry/Desktop/python/cancer detection/data/train/malignant/'

train_samples = 1970
validation_samples = 650
epochs = 30
batch_size = 8  #batch_size 

input_shape = (image_width, image_height, 3)

# %%
import os

train_benign_list = os.listdir(link_train_benign)
train_malignant_list = os.listdir(link_train_malignant)

# %%
rows = 4
columns = 4
num_ing = rows * columns

train_benign_img = []
train_malignant_img = []

for i in range (0,num_ing):
    train_benign_img.append(plt.imread(link_train_benign + train_benign_list[i]))
    train_malignant_img.append(plt.imread(link_train_malignant + train_malignant_list[i]))

fig_benign = plt.figure(figsize=(columns,rows))
plt.title('train_benign_img')
plt.xticks([])
plt.yticks([])

for i in range(num_ing):
    fig_benign.add_subplot(rows, columns, i+1)
    plt.imshow(train_benign_img[i])
    plt.xticks([])
    plt.yticks([])

plt.show()


fig_malignant = plt.figure(figsize=(columns,rows))
plt.title('train_malignant_img')
plt.xticks([])
plt.yticks([])

for i in range(num_ing):
    fig_malignant.add_subplot(rows, columns, i+1)
    plt.imshow(train_malignant_img[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %% [markdown]
# ## Prepairing train and validation datagens

# %%
# Setting augmentatoin parameters
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=360)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Creating train and validation datagens
train_processing = train_datagen.flow_from_directory(link_data_train,
                                                     target_size=(image_width, image_height), # Размер изображений
                                                     batch_size=batch_size, #Размер пакетов данных
                                                     class_mode='categorical') # Режим класса

validation_processing= test_datagen.flow_from_directory(link_data_test,
                                                        target_size=(image_width, image_height),
                                                        batch_size=batch_size,
                                                        class_mode='categorical')
# Out:
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.

# %% [markdown]
# ## Creating neural networks

# %%
def fit_gen(pattern_un):
    result = pattern_un.fit_generator(train_processing, # Помещаем обучающую выборку
                                 steps_per_epoch=train_samples / batch_size, #количество итераций пакета до того, как период обучения считается завершенным
                                 epochs=epochs, # Указываем количество эпох
                                 validation_data=validation_processing, # Помещаем проверочную выборку
                                 validation_steps=validation_samples/ batch_size)

    result_df = pd.DataFrame(result.history)
    return (result, result_df)

# %%
def show_res(result_df_un):
    display(result_df_un)

    result_df_un[['accuracy', 'val_accuracy']].plot()
    result_df_un[['loss', 'val_loss']].plot()

# %%
pattern = Sequential()

# 1-st layer
pattern.add(Conv2D(32, (3, 3), input_shape=input_shape))
pattern.add(Activation('relu'))
pattern.add(AveragePooling2D(pool_size=(2, 2)))

# 2-nd layer
pattern.add(Conv2D(32, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(AveragePooling2D(pool_size=(2, 2)))

# 3-rd layer
pattern.add(Conv2D(64, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(AveragePooling2D(pool_size=(2, 2)))

# 4-th layer
pattern.add(Conv2D(32, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(AveragePooling2D(pool_size=(2, 2)))

# 5-th layer
pattern.add(Conv2D(32, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(AveragePooling2D(pool_size=(2, 2)))

# Final layer: separation into 2 groups using "softmax" activation function
pattern.add(Flatten())
pattern.add(Dense(2))# число классов
pattern.add(Activation('softmax'))

# Compiling the neural network
pattern.compile(loss='categorical_crossentropy',
                optimizer='rmsprop',
                metrics=['accuracy'])

# %%
result, result_df = fit_gen(pattern)
# Out:
# Epoch 1/20
# /var/folders/tk/9chf0hp54s55zy3ttqs476dh0000gn/T/ipykernel_82566/2773942564.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   result = pattern_un.fit_generator(train_processing, # Помещаем обучающую выборку
# 123/123 [==============================] - 10s 75ms/step - loss: 0.6287 - accuracy: 0.6234 - val_loss: 0.6841 - val_accuracy: 0.6052
# Epoch 2/20
# 123/123 [==============================] - 9s 74ms/step - loss: 0.5152 - accuracy: 0.7405 - val_loss: 0.5340 - val_accuracy: 0.7012
# Epoch 3/20
# 123/123 [==============================] - 9s 73ms/step - loss: 0.4868 - accuracy: 0.7562 - val_loss: 0.4484 - val_accuracy: 0.7485
# Epoch 4/20
# 123/123 [==============================] - 9s 74ms/step - loss: 0.4720 - accuracy: 0.7678 - val_loss: 0.4163 - val_accuracy: 0.7759
# Epoch 5/20
# 123/123 [==============================] - 9s 75ms/step - loss: 0.4697 - accuracy: 0.7641 - val_loss: 0.3968 - val_accuracy: 0.8232
# Epoch 6/20
# 123/123 [==============================] - 9s 73ms/step - loss: 0.4416 - accuracy: 0.7908 - val_loss: 0.3898 - val_accuracy: 0.8049
# Epoch 7/20
# 123/123 [==============================] - 9s 75ms/step - loss: 0.4352 - accuracy: 0.7910 - val_loss: 0.3874 - val_accuracy: 0.8003
# Epoch 8/20
# 123/123 [==============================] - 9s 73ms/step - loss: 0.4471 - accuracy: 0.7839 - val_loss: 0.3910 - val_accuracy: 0.7957
# Epoch 9/20
# 123/123 [==============================] - 9s 75ms/step - loss: 0.4230 - accuracy: 0.7976 - val_loss: 0.4351 - val_accuracy: 0.7683
# Epoch 10/20
# 123/123 [==============================] - 9s 73ms/step - loss: 0.4136 - accuracy: 0.8026 - val_loss: 0.4144 - val_accuracy: 0.7881
# Epoch 11/20
# 123/123 [==============================] - 10s 78ms/step - loss: 0.4111 - accuracy: 0.8016 - val_loss: 0.4103 - val_accuracy: 0.7835
# Epoch 12/20
# 123/123 [==============================] - 9s 75ms/step - loss: 0.4201 - accuracy: 0.7890 - val_loss: 0.3957 - val_accuracy: 0.8003
# Epoch 13/20
# 123/123 [==============================] - 9s 73ms/step - loss: 0.3918 - accuracy: 0.8155 - val_loss: 0.3920 - val_accuracy: 0.8155
# Epoch 14/20
# 123/123 [==============================] - 9s 75ms/step - loss: 0.3881 - accuracy: 0.8193 - val_loss: 0.3811 - val_accuracy: 0.8064
# Epoch 15/20
# 123/123 [==============================] - 9s 74ms/step - loss: 0.3965 - accuracy: 0.8117 - val_loss: 0.3799 - val_accuracy: 0.8186
# Epoch 16/20
# 123/123 [==============================] - 9s 75ms/step - loss: 0.3936 - accuracy: 0.8145 - val_loss: 0.4376 - val_accuracy: 0.8003
# Epoch 17/20
# 123/123 [==============================] - 9s 75ms/step - loss: 0.3938 - accuracy: 0.8170 - val_loss: 0.3666 - val_accuracy: 0.8201
# Epoch 18/20
# 123/123 [==============================] - 9s 76ms/step - loss: 0.3900 - accuracy: 0.8183 - val_loss: 0.3499 - val_accuracy: 0.8095
# Epoch 19/20
# 123/123 [==============================] - 11s 90ms/step - loss: 0.3927 - accuracy: 0.8046 - val_loss: 0.3590 - val_accuracy: 0.8110
# Epoch 20/20
# 123/123 [==============================] - 9s 74ms/step - loss: 0.3794 - accuracy: 0.8173 - val_loss: 0.5077 - val_accuracy: 0.7149

# %%
show_res(result_df)
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.628688  0.623423  0.684079      0.605183
# 1   0.515238  0.740535  0.533963      0.701219
# 2   0.486752  0.756184  0.448381      0.748476
# 3   0.472007  0.767794  0.416288      0.775915
# 4   0.469706  0.764113  0.396788      0.823171
# 5   0.441585  0.790827  0.389767      0.804878
# 6   0.435207  0.791015  0.387397      0.800305
# 7   0.447098  0.783948  0.390976      0.795732
# 8   0.422982  0.797577  0.435136      0.768293
# 9   0.413589  0.802625  0.414413      0.788110
# 10  0.411126  0.801615  0.410278      0.783537
# 11  0.420149  0.788995  0.395723      0.800305
# 12  0.391821  0.815524  0.392008      0.815549
# 13  0.388098  0.819283  0.381145      0.806402
# 14  0.396506  0.811711  0.379867      0.818598
# 15  0.393581  0.814516  0.437642      0.800305
# 16  0.393817  0.817036  0.366556      0.820122
# 17  0.389986  0.818274  0.349863      0.809451
# 18  0.392739  0.804644  0.359036      0.810976
# 19  0.379375  0.817264  0.507668      0.714939

# %%
pattern = Sequential()

# 1-st layer
pattern.add(Conv2D(16, (3, 3), input_shape=input_shape))
pattern.add(Activation('relu'))
pattern.add(AveragePooling2D(pool_size=(2, 2)))

# 2-nd layer
#pattern.add(Conv2D(16, (3, 3)))
#pattern.add(Activation('relu'))
#pattern.add(AveragePooling2D(pool_size=(2, 2)))

# 3-rd layer
#pattern.add(Conv2D(32, (3, 3)))
#pattern.add(Activation('relu'))
#pattern.add(AveragePooling2D(pool_size=(2, 2)))

# 4-th layer
#pattern.add(Conv2D(16, (3, 3)))
#pattern.add(Activation('relu'))
#pattern.add(AveragePooling2D(pool_size=(2, 2)))

# 5-th layer
#pattern.add(Conv2D(16, (3, 3)))
#pattern.add(Activation('relu'))
#pattern.add(AveragePooling2D(pool_size=(2, 2)))

# Final layer: separation into 2 groups using "softmax" activation function
pattern.add(Flatten())
pattern.add(Dense(2))# число классов
pattern.add(Activation('softmax'))

# Compiling the neural network
pattern.compile(loss='categorical_crossentropy',
                optimizer='rmsprop',
                metrics=['accuracy'])

# %%
result, result_df = fit_gen(pattern)
# Out:
# Epoch 1/20
# /var/folders/tk/9chf0hp54s55zy3ttqs476dh0000gn/T/ipykernel_82566/2773942564.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   result = pattern_un.fit_generator(train_processing, # Помещаем обучающую выборку
# 123/123 [==============================] - 8s 62ms/step - loss: 1.0034 - accuracy: 0.6719 - val_loss: 0.4610 - val_accuracy: 0.7409
# Epoch 2/20
# 123/123 [==============================] - 7s 54ms/step - loss: 0.4994 - accuracy: 0.7521 - val_loss: 0.5381 - val_accuracy: 0.7302
# Epoch 3/20
# 123/123 [==============================] - 6s 49ms/step - loss: 0.4840 - accuracy: 0.7668 - val_loss: 0.3942 - val_accuracy: 0.8034
# Epoch 4/20
# 123/123 [==============================] - 5s 38ms/step - loss: 0.4386 - accuracy: 0.7797 - val_loss: 0.3843 - val_accuracy: 0.8018
# Epoch 5/20
# 123/123 [==============================] - 5s 37ms/step - loss: 0.4247 - accuracy: 0.8062 - val_loss: 0.4157 - val_accuracy: 0.7896
# Epoch 6/20
# 123/123 [==============================] - 5s 39ms/step - loss: 0.4072 - accuracy: 0.7996 - val_loss: 0.4536 - val_accuracy: 0.8034
# Epoch 7/20
# 123/123 [==============================] - 5s 39ms/step - loss: 0.3919 - accuracy: 0.8198 - val_loss: 0.4229 - val_accuracy: 0.7790
# Epoch 8/20
# 123/123 [==============================] - 5s 38ms/step - loss: 0.3987 - accuracy: 0.8309 - val_loss: 0.3422 - val_accuracy: 0.8293
# Epoch 9/20
# 123/123 [==============================] - 5s 38ms/step - loss: 0.3586 - accuracy: 0.8276 - val_loss: 0.3892 - val_accuracy: 0.8095
# Epoch 10/20
# 123/123 [==============================] - 5s 39ms/step - loss: 0.3665 - accuracy: 0.8258 - val_loss: 0.3666 - val_accuracy: 0.7988
# Epoch 11/20
# 123/123 [==============================] - 5s 38ms/step - loss: 0.3644 - accuracy: 0.8306 - val_loss: 0.3588 - val_accuracy: 0.8399
# Epoch 12/20
# 123/123 [==============================] - 5s 38ms/step - loss: 0.3351 - accuracy: 0.8438 - val_loss: 0.3640 - val_accuracy: 0.8216
# Epoch 13/20
# 123/123 [==============================] - 5s 39ms/step - loss: 0.3294 - accuracy: 0.8501 - val_loss: 0.3486 - val_accuracy: 0.8354
# Epoch 14/20
# 123/123 [==============================] - 5s 38ms/step - loss: 0.3417 - accuracy: 0.8531 - val_loss: 0.3310 - val_accuracy: 0.8308
# Epoch 15/20
# 123/123 [==============================] - 5s 38ms/step - loss: 0.3145 - accuracy: 0.8536 - val_loss: 0.3587 - val_accuracy: 0.8277
# Epoch 16/20
# 123/123 [==============================] - 5s 40ms/step - loss: 0.3159 - accuracy: 0.8672 - val_loss: 0.3287 - val_accuracy: 0.8338
# Epoch 17/20
# 123/123 [==============================] - 5s 38ms/step - loss: 0.3087 - accuracy: 0.8647 - val_loss: 0.4356 - val_accuracy: 0.8201
# Epoch 18/20
# 123/123 [==============================] - 5s 38ms/step - loss: 0.3193 - accuracy: 0.8576 - val_loss: 0.3499 - val_accuracy: 0.8140
# Epoch 19/20
# 123/123 [==============================] - 5s 38ms/step - loss: 0.3049 - accuracy: 0.8698 - val_loss: 0.5717 - val_accuracy: 0.7637
# Epoch 20/20
# 123/123 [==============================] - 5s 40ms/step - loss: 0.2813 - accuracy: 0.8693 - val_loss: 0.3626 - val_accuracy: 0.8140

# %%
show_res(result_df)
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.003436  0.671883  0.461030      0.740854
# 1   0.499363  0.752145  0.538085      0.730183
# 2   0.483961  0.766784  0.394172      0.803354
# 3   0.438636  0.779738  0.384311      0.801829
# 4   0.424664  0.806158  0.415655      0.789634
# 5   0.407240  0.799596  0.453600      0.803354
# 6   0.391878  0.819788  0.422873      0.778963
# 7   0.398706  0.830894  0.342178      0.829268
# 8   0.358644  0.827621  0.389182      0.809451
# 9   0.366505  0.825846  0.366591      0.798781
# 10  0.364440  0.830645  0.358787      0.839939
# 11  0.335064  0.843750  0.363998      0.821646
# 12  0.329383  0.850076  0.348558      0.835366
# 13  0.341737  0.853104  0.331028      0.830793
# 14  0.314496  0.853609  0.358694      0.827744
# 15  0.315876  0.867239  0.328667      0.833841
# 16  0.308729  0.864715  0.435628      0.820122
# 17  0.319285  0.857648  0.349899      0.814024
# 18  0.304900  0.869763  0.571680      0.763719
# 19  0.281267  0.869258  0.362633      0.814024

# %%
pattern = Sequential()

# 1-st layer
pattern.add(Conv2D(8, (3, 3), input_shape=input_shape))
pattern.add(Activation('relu'))
pattern.add(AveragePooling2D(pool_size=(2, 2)))

# 2-nd layer
pattern.add(Conv2D(8, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(AveragePooling2D(pool_size=(2, 2)))

# 3-rd layer
pattern.add(Conv2D(8, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(AveragePooling2D(pool_size=(2, 2)))

# Final layer: separation into 2 groups using "softmax" activation function
pattern.add(Flatten())
pattern.add(Dense(2))# число классов
pattern.add(Activation('softmax'))

# Compiling the neural network
pattern.compile(loss='categorical_crossentropy',
                optimizer='rmsprop',
                metrics=['accuracy'])

# %%
result_qwe, result_df_qwe = fit_gen(pattern)
# Out:
# Epoch 1/30
# /var/folders/tk/9chf0hp54s55zy3ttqs476dh0000gn/T/ipykernel_82947/2773942564.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   result = pattern_un.fit_generator(train_processing, # Помещаем обучающую выборку
# 246/246 [==============================] - 9s 34ms/step - loss: 0.5901 - accuracy: 0.6690 - val_loss: 0.5930 - val_accuracy: 0.6936
# Epoch 2/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.5005 - accuracy: 0.7415 - val_loss: 0.4688 - val_accuracy: 0.7607
# Epoch 3/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.4721 - accuracy: 0.7475 - val_loss: 0.4272 - val_accuracy: 0.8018
# Epoch 4/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.4582 - accuracy: 0.7663 - val_loss: 0.4536 - val_accuracy: 0.7881
# Epoch 5/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.4429 - accuracy: 0.7753 - val_loss: 0.4359 - val_accuracy: 0.7607
# Epoch 6/30
# 246/246 [==============================] - 7s 30ms/step - loss: 0.4401 - accuracy: 0.7745 - val_loss: 0.3899 - val_accuracy: 0.8034
# Epoch 7/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.4238 - accuracy: 0.7849 - val_loss: 0.3775 - val_accuracy: 0.8247
# Epoch 8/30
# 246/246 [==============================] - 7s 30ms/step - loss: 0.4235 - accuracy: 0.7851 - val_loss: 0.3797 - val_accuracy: 0.8110
# Epoch 9/30
# 246/246 [==============================] - 8s 34ms/step - loss: 0.4181 - accuracy: 0.7912 - val_loss: 0.4780 - val_accuracy: 0.7195
# Epoch 10/30
# 246/246 [==============================] - 9s 35ms/step - loss: 0.4168 - accuracy: 0.7961 - val_loss: 0.3733 - val_accuracy: 0.8308
# Epoch 11/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.4076 - accuracy: 0.8120 - val_loss: 0.3892 - val_accuracy: 0.8095
# Epoch 12/30
# 246/246 [==============================] - 7s 30ms/step - loss: 0.4046 - accuracy: 0.8003 - val_loss: 0.4903 - val_accuracy: 0.7835
# Epoch 13/30
# 246/246 [==============================] - 7s 30ms/step - loss: 0.4153 - accuracy: 0.7986 - val_loss: 0.3562 - val_accuracy: 0.8354
# Epoch 14/30
# 246/246 [==============================] - 7s 30ms/step - loss: 0.4040 - accuracy: 0.8011 - val_loss: 0.3524 - val_accuracy: 0.8338
# Epoch 15/30
# 246/246 [==============================] - 8s 33ms/step - loss: 0.4035 - accuracy: 0.8064 - val_loss: 0.3643 - val_accuracy: 0.8293
# Epoch 16/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.3923 - accuracy: 0.8099 - val_loss: 0.3584 - val_accuracy: 0.8369
# Epoch 17/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.4021 - accuracy: 0.8049 - val_loss: 0.3834 - val_accuracy: 0.8201
# Epoch 18/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.3874 - accuracy: 0.8130 - val_loss: 0.3491 - val_accuracy: 0.8384
# Epoch 19/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.3938 - accuracy: 0.8059 - val_loss: 0.3570 - val_accuracy: 0.8354
# Epoch 20/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.3909 - accuracy: 0.8102 - val_loss: 0.3663 - val_accuracy: 0.8262
# Epoch 21/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.3969 - accuracy: 0.8109 - val_loss: 0.3745 - val_accuracy: 0.8140
# Epoch 22/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.3820 - accuracy: 0.8155 - val_loss: 0.3676 - val_accuracy: 0.8155
# Epoch 23/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.3921 - accuracy: 0.8094 - val_loss: 0.3428 - val_accuracy: 0.8354
# Epoch 24/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.3796 - accuracy: 0.8272 - val_loss: 0.3549 - val_accuracy: 0.8186
# Epoch 25/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.3839 - accuracy: 0.8178 - val_loss: 0.3426 - val_accuracy: 0.8369
# Epoch 26/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.3832 - accuracy: 0.8180 - val_loss: 0.3572 - val_accuracy: 0.8277
# Epoch 27/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.3693 - accuracy: 0.8236 - val_loss: 0.3626 - val_accuracy: 0.8095
# Epoch 28/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.3742 - accuracy: 0.8221 - val_loss: 0.3424 - val_accuracy: 0.8491
# Epoch 29/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.3740 - accuracy: 0.8165 - val_loss: 0.3510 - val_accuracy: 0.8460
# Epoch 30/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.3801 - accuracy: 0.8231 - val_loss: 0.3594 - val_accuracy: 0.8308

# %%
show_res(result_df_qwe)
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.590129  0.669028  0.593007      0.693598
# 1   0.500466  0.741510  0.468825      0.760671
# 2   0.472050  0.747470  0.427231      0.801829
# 3   0.458198  0.766346  0.453594      0.788110
# 4   0.442859  0.775304  0.435933      0.760671
# 5   0.440091  0.774455  0.389917      0.803354
# 6   0.423812  0.784919  0.377475      0.824695
# 7   0.423494  0.785099  0.379736      0.810976
# 8   0.418088  0.791181  0.478022      0.719512
# 9   0.416841  0.796053  0.373342      0.830793
# 10  0.407627  0.811961  0.389170      0.809451
# 11  0.404634  0.800304  0.490344      0.783537
# 12  0.415254  0.798583  0.356176      0.835366
# 13  0.403959  0.801113  0.352412      0.833841
# 14  0.403459  0.806386  0.364270      0.829268
# 15  0.392253  0.809934  0.358438      0.836890
# 16  0.402104  0.804866  0.383436      0.820122
# 17  0.387368  0.812975  0.349137      0.838415
# 18  0.393750  0.805879  0.357048      0.835366
# 19  0.390921  0.810223  0.366325      0.826219
# 20  0.396864  0.810948  0.374528      0.814024
# 21  0.382014  0.815509  0.367644      0.815549
# 22  0.392090  0.809427  0.342835      0.835366
# 23  0.379552  0.827167  0.354896      0.818598
# 24  0.383861  0.817814  0.342586      0.836890
# 25  0.383217  0.818044  0.357248      0.827744
# 26  0.369304  0.823619  0.362568      0.809451
# 27  0.374240  0.822098  0.342411      0.849085
# 28  0.373952  0.816523  0.350982      0.846037
# 29  0.380054  0.823112  0.359399      0.830793

# %%
pattern = Sequential()

# 1-st layer
pattern.add(Conv2D(5, (3, 3), input_shape=input_shape))
pattern.add(Activation('relu'))
pattern.add(AveragePooling2D(pool_size=(2, 2)))

# 2-nd layer
#pattern.add(Conv2D(16, (3, 3)))
#pattern.add(Activation('relu'))
#pattern.add(AveragePooling2D(pool_size=(2, 2)))

# 3-rd layer
#pattern.add(Conv2D(16, (3, 3)))
#pattern.add(Activation('relu'))
#pattern.add(AveragePooling2D(pool_size=(2, 2)))

# Final layer: separation into 2 groups using "softmax" activation function
pattern.add(Flatten())
pattern.add(Dense(120))
pattern.add(Activation('softmax'))
pattern.add(Dense(32))
pattern.add(Activation('softmax'))
pattern.add(Dense(2))
pattern.add(Activation('softmax'))

# Compiling the neural network
pattern.compile(loss='categorical_crossentropy',
                optimizer='rmsprop',
                metrics=['accuracy'])

# %%
result, result_df = fit_gen(pattern)
# Out:
# Epoch 1/30
# /var/folders/tk/9chf0hp54s55zy3ttqs476dh0000gn/T/ipykernel_82947/2773942564.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   result = pattern_un.fit_generator(train_processing, # Помещаем обучающую выборку
# 246/246 [==============================] - 10s 38ms/step - loss: 0.6897 - accuracy: 0.5464 - val_loss: 0.6892 - val_accuracy: 0.5442
# Epoch 2/30
# 246/246 [==============================] - 8s 33ms/step - loss: 0.6833 - accuracy: 0.5489 - val_loss: 0.6838 - val_accuracy: 0.5473
# Epoch 3/30
# 246/246 [==============================] - 8s 34ms/step - loss: 0.6722 - accuracy: 0.5423 - val_loss: 0.6533 - val_accuracy: 0.5442
# Epoch 4/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.6450 - accuracy: 0.6220 - val_loss: 0.6525 - val_accuracy: 0.6692
# Epoch 5/30
# 246/246 [==============================] - 8s 33ms/step - loss: 0.6062 - accuracy: 0.7495 - val_loss: 0.5762 - val_accuracy: 0.7774
# Epoch 6/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.5612 - accuracy: 0.7694 - val_loss: 0.5452 - val_accuracy: 0.7622
# Epoch 7/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.5410 - accuracy: 0.7627 - val_loss: 0.5119 - val_accuracy: 0.7713
# Epoch 8/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.5143 - accuracy: 0.7669 - val_loss: 0.5225 - val_accuracy: 0.7409
# Epoch 9/30
# 246/246 [==============================] - 8s 34ms/step - loss: 0.5130 - accuracy: 0.7689 - val_loss: 0.6276 - val_accuracy: 0.6768
# Epoch 10/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.4808 - accuracy: 0.7785 - val_loss: 0.4681 - val_accuracy: 0.7881
# Epoch 11/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.4686 - accuracy: 0.7836 - val_loss: 0.4508 - val_accuracy: 0.7942
# Epoch 12/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.4501 - accuracy: 0.8018 - val_loss: 0.4370 - val_accuracy: 0.7973
# Epoch 13/30
# 246/246 [==============================] - 9s 34ms/step - loss: 0.4456 - accuracy: 0.7945 - val_loss: 0.4334 - val_accuracy: 0.7957
# Epoch 14/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.4589 - accuracy: 0.7856 - val_loss: 0.4476 - val_accuracy: 0.7729
# Epoch 15/30
# 246/246 [==============================] - 8s 33ms/step - loss: 0.4536 - accuracy: 0.7881 - val_loss: 0.4370 - val_accuracy: 0.7866
# Epoch 16/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.4432 - accuracy: 0.7907 - val_loss: 0.4255 - val_accuracy: 0.7957
# Epoch 17/30
# 246/246 [==============================] - 8s 33ms/step - loss: 0.4281 - accuracy: 0.8001 - val_loss: 0.4120 - val_accuracy: 0.8018
# Epoch 18/30
# 246/246 [==============================] - 8s 32ms/step - loss: 0.4395 - accuracy: 0.7900 - val_loss: 0.4146 - val_accuracy: 0.7973
# Epoch 19/30
# 246/246 [==============================] - 8s 33ms/step - loss: 0.4233 - accuracy: 0.8049 - val_loss: 0.4206 - val_accuracy: 0.7851
# Epoch 20/30
# 246/246 [==============================] - 8s 34ms/step - loss: 0.4227 - accuracy: 0.7937 - val_loss: 0.4062 - val_accuracy: 0.7927
# Epoch 21/30
# 246/246 [==============================] - 8s 33ms/step - loss: 0.4155 - accuracy: 0.8001 - val_loss: 0.4216 - val_accuracy: 0.7927
# Epoch 22/30
# 246/246 [==============================] - 7s 30ms/step - loss: 0.4152 - accuracy: 0.8018 - val_loss: 0.4227 - val_accuracy: 0.7683
# Epoch 23/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.4226 - accuracy: 0.7940 - val_loss: 0.4161 - val_accuracy: 0.7866
# Epoch 24/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.4230 - accuracy: 0.7973 - val_loss: 0.4072 - val_accuracy: 0.7988
# Epoch 25/30
# 246/246 [==============================] - 7s 30ms/step - loss: 0.4230 - accuracy: 0.7922 - val_loss: 0.4068 - val_accuracy: 0.7896
# Epoch 26/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.4112 - accuracy: 0.7993 - val_loss: 0.4526 - val_accuracy: 0.7363
# Epoch 27/30
# 246/246 [==============================] - 8s 31ms/step - loss: 0.3943 - accuracy: 0.8039 - val_loss: 0.3834 - val_accuracy: 0.7988
# Epoch 28/30
# 246/246 [==============================] - 8s 34ms/step - loss: 0.3922 - accuracy: 0.8099 - val_loss: 0.4224 - val_accuracy: 0.7881
# Epoch 29/30
# 246/246 [==============================] - 8s 33ms/step - loss: 0.4139 - accuracy: 0.8072 - val_loss: 0.3788 - val_accuracy: 0.8034
# Epoch 30/30
# 246/246 [==============================] - 8s 33ms/step - loss: 0.3858 - accuracy: 0.8120 - val_loss: 0.4178 - val_accuracy: 0.7957

# %%
show_res(result_df)
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.689713  0.546376  0.689234      0.544207
# 1   0.683302  0.548910  0.683782      0.547256
# 2   0.672233  0.542321  0.653292      0.544207
# 3   0.644974  0.621964  0.652464      0.669207
# 4   0.606182  0.749494  0.576236      0.777439
# 5   0.561185  0.769387  0.545211      0.762195
# 6   0.540976  0.762652  0.511897      0.771341
# 7   0.514350  0.766852  0.522477      0.740854
# 8   0.513015  0.768880  0.627567      0.676829
# 9   0.480816  0.778510  0.468144      0.788110
# 10  0.468648  0.783578  0.450821      0.794207
# 11  0.450121  0.801825  0.436991      0.797256
# 12  0.445576  0.794534  0.433449      0.795732
# 13  0.458872  0.785606  0.447579      0.772866
# 14  0.453612  0.788140  0.436961      0.786585
# 15  0.443159  0.790674  0.425481      0.795732
# 16  0.428145  0.800101  0.411972      0.801829
# 17  0.439477  0.789980  0.414617      0.797256
# 18  0.423292  0.804866  0.420570      0.785061
# 19  0.422748  0.793715  0.406229      0.792683
# 20  0.415493  0.800101  0.421585      0.792683
# 21  0.415226  0.801825  0.422652      0.768293
# 22  0.422555  0.794028  0.416059      0.786585
# 23  0.422988  0.797263  0.407207      0.798781
# 24  0.423014  0.792195  0.406808      0.789634
# 25  0.411222  0.799290  0.452564      0.736281
# 26  0.394259  0.803852  0.383416      0.798781
# 27  0.392207  0.809934  0.422437      0.788110
# 28  0.413901  0.807186  0.378814      0.803354
# 29  0.385811  0.811961  0.417840      0.795732

# %%
#100
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPooling2D, AveragePooling2D

pattern = Sequential() # Создание модели

# Первый слой нейросети
pattern.add(Conv2D(8, (3, 3), input_shape=input_shape))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Второй слой нейросети
pattern.add(Conv2D(8, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(AveragePooling2D(pool_size=(2, 2)))

# Третий слой нейросети
pattern.add(Conv2D(8, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(AveragePooling2D(pool_size=(2, 2)))

#Aктивация, свертка, объединение, исключение
pattern.add(Flatten())
pattern.add(Dense(120))# число классов
pattern.add(Dense(32))# число классов
pattern.add(Dense(2))# число классов
pattern.add(Activation('softmax'))

#Cкомпилируем модель с выбранными параметрами. Также укажем метрику для оценки.
pattern.compile(loss='categorical_crossentropy',
                optimizer='rmsprop',
                metrics=['accuracy'])


# Задаём параметры аугментации
train_datagen = ImageDataGenerator(rescale=1./255,
                                   #shear_range=0.2,
                                   #zoom_range=0.2,
                                   horizontal_flip=360)
test_datagen = ImageDataGenerator(rescale=1./255)

qwe3 = pattern.fit_generator(train_processing, # Помещаем обучающую выборку
                      steps_per_epoch=train_samples / batch_size, #количество итераций пакета до того, как период обучения считается завершенным
                      epochs=epochs, # Указываем количество эпох
                      validation_data=validation_processing, # Помещаем проверочную выборку
                      validation_steps=validation_samples/ batch_size)

qwe3_df = pd.DataFrame(qwe3.history)
#display(qwe3_df)
qwe3_df[['accuracy', 'val_accuracy']].plot()

qwe3_df[['loss', 'val_loss']].plot()
# Out:
# Epoch 1/30
# /var/folders/tk/9chf0hp54s55zy3ttqs476dh0000gn/T/ipykernel_41794/2726376578.py:41: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   qwe3 = pattern.fit_generator(train_processing, # Помещаем обучающую выборку
# 656/656 [==============================] - 9s 13ms/step - loss: 0.6065 - accuracy: 0.6677 - val_loss: 0.4673 - val_accuracy: 0.7727
# Epoch 2/30
# 656/656 [==============================] - 7s 11ms/step - loss: 0.5237 - accuracy: 0.7397 - val_loss: 0.4409 - val_accuracy: 0.7696
# Epoch 3/30
# 656/656 [==============================] - 7s 10ms/step - loss: 0.4999 - accuracy: 0.7494 - val_loss: 0.4651 - val_accuracy: 0.7696
# Epoch 4/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4822 - accuracy: 0.7626 - val_loss: 0.5212 - val_accuracy: 0.7834
# Epoch 5/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4775 - accuracy: 0.7752 - val_loss: 0.4209 - val_accuracy: 0.7880
# Epoch 6/30
# 656/656 [==============================] - 6s 10ms/step - loss: 0.4706 - accuracy: 0.7813 - val_loss: 0.4304 - val_accuracy: 0.7896
# Epoch 7/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4729 - accuracy: 0.7717 - val_loss: 0.4038 - val_accuracy: 0.7988
# Epoch 8/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4509 - accuracy: 0.7844 - val_loss: 0.4012 - val_accuracy: 0.8034
# Epoch 9/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4739 - accuracy: 0.7829 - val_loss: 0.4279 - val_accuracy: 0.7819
# Epoch 10/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4682 - accuracy: 0.7829 - val_loss: 0.3914 - val_accuracy: 0.8141
# Epoch 11/30
# 656/656 [==============================] - 6s 10ms/step - loss: 0.4512 - accuracy: 0.7935 - val_loss: 0.4849 - val_accuracy: 0.8187
# Epoch 12/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4295 - accuracy: 0.7950 - val_loss: 0.3850 - val_accuracy: 0.8095
# Epoch 13/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4441 - accuracy: 0.8042 - val_loss: 0.3687 - val_accuracy: 0.8310
# Epoch 14/30
# 656/656 [==============================] - 6s 10ms/step - loss: 0.4423 - accuracy: 0.7950 - val_loss: 0.4419 - val_accuracy: 0.7972
# Epoch 15/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4323 - accuracy: 0.8092 - val_loss: 0.4124 - val_accuracy: 0.8141
# Epoch 16/30
# 656/656 [==============================] - 6s 10ms/step - loss: 0.4462 - accuracy: 0.7986 - val_loss: 0.3964 - val_accuracy: 0.7926
# Epoch 17/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4191 - accuracy: 0.8067 - val_loss: 0.3885 - val_accuracy: 0.8065
# Epoch 18/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4335 - accuracy: 0.8001 - val_loss: 0.3706 - val_accuracy: 0.8141
# Epoch 19/30
# 656/656 [==============================] - 6s 10ms/step - loss: 0.4408 - accuracy: 0.7925 - val_loss: 0.3835 - val_accuracy: 0.8203
# Epoch 20/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4453 - accuracy: 0.8016 - val_loss: 0.5599 - val_accuracy: 0.8065
# Epoch 21/30
# 656/656 [==============================] - 6s 10ms/step - loss: 0.4455 - accuracy: 0.7976 - val_loss: 0.3670 - val_accuracy: 0.8141
# Epoch 22/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4378 - accuracy: 0.7991 - val_loss: 0.4427 - val_accuracy: 0.7865
# Epoch 23/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4433 - accuracy: 0.7935 - val_loss: 0.3987 - val_accuracy: 0.8065
# Epoch 24/30
# 656/656 [==============================] - 6s 10ms/step - loss: 0.4197 - accuracy: 0.8133 - val_loss: 0.3566 - val_accuracy: 0.8280
# Epoch 25/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4315 - accuracy: 0.8006 - val_loss: 0.3837 - val_accuracy: 0.8095
# Epoch 26/30
# 656/656 [==============================] - 6s 10ms/step - loss: 0.4464 - accuracy: 0.8092 - val_loss: 0.3654 - val_accuracy: 0.8356
# Epoch 27/30
# 656/656 [==============================] - 6s 10ms/step - loss: 0.4400 - accuracy: 0.8021 - val_loss: 0.4258 - val_accuracy: 0.8111
# Epoch 28/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4372 - accuracy: 0.8087 - val_loss: 0.4234 - val_accuracy: 0.8187
# Epoch 29/30
# 656/656 [==============================] - 6s 10ms/step - loss: 0.4399 - accuracy: 0.8026 - val_loss: 0.3576 - val_accuracy: 0.8356
# Epoch 30/30
# 656/656 [==============================] - 6s 9ms/step - loss: 0.4366 - accuracy: 0.8108 - val_loss: 0.4210 - val_accuracy: 0.8080
# <Axes: >

# %%
pattern.save_weights('first_model_weights.h5') #Сохранение весов модели
pattern.save('path') #Сохранение модели
pattern.load_weights('first_model_weights.h5') # Загрузка весов модели
prediction = pattern.predict(validation_processing) #Использование модели для предсказания
# Out:
# INFO:tensorflow:Assets written to: path/assets
# INFO:tensorflow:Assets written to: path/assets
# 660/660 [==============================] - 2s 3ms/step
